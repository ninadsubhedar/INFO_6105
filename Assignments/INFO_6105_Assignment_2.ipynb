# %% [markdown]
# ## Assignment 2 - Linear Models
#
# **Due Friday, February 22, 2019**
#
# _Submission: Put the data and Jupyter notebook files in a folder. Make sure all links to data are relative to the folder so the TAs can run the notebooks._   Points will be deducted if the TAs can't run the notebooks.
#
# Find a public dataset with a least 9 columns and 3000 rows. You must post your dataset on the class piazza or google spreadsheet (whatever the TAs set-up) and get an OK before using it as every student needs to use a different dataset.
#
# In this assingment you will create predictive linear models using BOTH linear and logistic regression.
#
#
# ## Part A  - Linear model (20 points)
#
# * Generate linear models for your data:
#
#     * Find a significant linear relations of your choosing in your data. Create a multivariate (multiple independent variable) linear models.
#
# You MUST use at least 5 independent variables and at least one independent variable needs to be a binary categorical variable and  at least one independent variable needs to be a multi-class categorical variable.
#
# You MUST generate at least three models.
#
# Answer the following questions for the multivariate (multiple) linear models:
#     * Is the relationship significant?
#     * Are any model assumptions violated?
#     * Does the model make sense? Interpret the meaning of each independent variable.
#     * Cross-validate the model. How well did it do?
#     * Compare the AIC, BIC and adjusted R^2.  Do they agree in their ranking of the models?
#
# See [Simple Linear Regression and Confidence Intervals (13:01)](https://www.youtube.com/watch?v=PsE9UqoWtS4)
# and
#
# [Multiple Linear Regression and Interpreting Regression Coefficients (15:38)](https://www.youtube.com/watch?v=1hbCJyM9ccs)
#
# and
#
# [Model Selection and Qualitative Predictors (14:51)](https://www.youtube.com/watch?v=3T6RXmIHbJ4)
#
#
# ## Part B  - Logistic model (20 points)
#
# * Generate logistic models for your data:
#
#     * Predict the probability of a two-class dependent variable using logistic regression.
#
# You MUST use at least 5 independent variables and at least one independent variable needs to be a binary categorical variable and  at least one independent variable needs to be a multi-class categorical variable.
#
# You MUST generate at least three models.
#
# Answer the following questions for the multivariate (multiple) linear models:
#     * Is the relationship significant?
#     * Are any model assumptions violated?
#     * Does the model make sense?  Interpret the meaning of each independent variable.
#     * Cross-validate the model. How well did it do?
#     * Calculate the probability of getting the dependent variable
#
# See [Logistic Regression and Maximum Likelihood (9:07)](https://www.youtube.com/watch?v=31Q5FGRnxt4)
#
#
# ## Part C - Multi-colinearity and step-wise regression  (10 points)
#
# Check for  multi-colinearity and perform step-wise regression for EITHER the logistic or linear model.
#
# Answer the following:
#
#         * Is there any multi-colinearity in the model?
#     * In the multiple regression models are predictor variables independent of all the other predictor variables?
#     * In multiple regression models rank the most significant predictor variables and exclude insignificant ones from the model.
#     * Cross-validate the models. How well did they do?
#
# See
#
#
# ## Part D -  Interaction effects (10 points)
#
# Create at least two product terms to model two likely interaction effects.
# * Is there a significant synergy (interaction effect) in either of your tested product terms?
#
# See [Interactions and Nonlinearity (14:16)](https://www.youtube.com/watch?v=IFzVxLv0TKQ)
#
#
#
# ## Part E -  Regularization (10 points)
#
# Use either L1 or L2 regularization for linear regression.  Compare the out of sample performance with non-regularized linear regression.
#
# **20 Points Format**
#
#  An assignment must have:
#
#  * an abstract
#  * explanations of the analysis and interpretations of figures and graphs
#  * a conclusion
#  * contributions statement
#  * citations
#  * a license
#
# [See Shrinkage Methods and Ridge Regression (12:37)]()
#
# **10 Points Professional Code**
#
# * Style guide
# * Consistent Naming Scheme
# * Commenting & Documentation
# * Consistent Indentation
# * DRY Principle/Cookie Cutter (DRY stands for Don't Repeat Yourself)
# * File and Folder Organization
# * Separation of Code and Data
# * Use Efficient Data Structures and Algorithms
# * Keep Your Code Portable
#
#
# **Group Size**
#
# One person.

# %% [markdown]
# Last update October 3, 2017
